# %%
import scipy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# グラフをインラインで表示させる
# %matplotlib inline

# Pandasでの表示が省略されないように設定
pd.set_option("max_columns", 100)
pd.set_option('max_rows',100)
pd.set_option('max_info_columns',100)

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
condition_2 = pd.read_csv("condition_add.csv")
stadium = pd.read_csv("stadium.csv")
add2014 = pd.read_csv("2014_add.csv")
train_add = pd.read_csv("train_add.csv")
train_new = pd.read_csv("train_new.csv")

# %%
train["stadium"] = train["stadium"].astype('str')
stadium_map = {'名古屋市瑞穂陸上競技場': 20000,
               '豊田スタジアム': 40000,
               '札幌ドーム': 39232,
               '札幌厚別公園競技場': 19620,
               'ノエビアスタジアム神戸': 30132,
               '県立カシマサッカースタジアム': 40728,
               'ケーズデンキスタジアム水戸': 12000,
               '鹿児島県立鴨池陸上競技場 ': 19934,
               '等々力陸上競技場': 26530,
 '日産スタジアム': 72327,
 'ニッパツ三ツ沢球技場': 15454,
 'Ｓｈｏｎａｎ\u3000ＢＭＷスタジアム平塚': 15100,
 'フクダ電子アリーナ': 18500,
 'うまかな・よかなスタジアム': 32000,
 '熊本市水前寺競技場': 15000,
 '京都市西京極総合運動公園陸上競技場兼球技場': 20588,
 'ユアテックスタジアム仙台': 19694,
 '松本平広域公園総合球技場': 20396,
'デンカビッグスワンスタジアム': 42300,
 '大分銀行ドーム': 40000,
 'シティライトスタジアム': 20000,
 '万博記念競技場': 21000,
 'キンチョウスタジアム': 19628,
 '日立柏サッカー場': 15349,
 'ヤンマースタジアム長居': 47816,
 'ベストアメニティスタジアム': 24490,
 '佐賀県総合運動場陸上競技場': 17000,
 '埼玉スタジアム２００２': 63700,
 'ＮＡＣＫ５スタジアム大宮': 15600,
 'ＩＡＩスタジアム日本平': 20281,
 'エコパスタジアム': 50889,
 'ヤマハスタジアム（磐田）': 15165,
 '栃木県グリーンスタジアム': 15589,
 '鳴門・大塚スポーツパーク\u3000ポカリスエットスタジアム': 19637,
 'ニンジニアスタジアム': 15576,
 '味の素スタジアム': 49970,
 '町田市立陸上競技場': 10328,
 '国立競技場': 54224,
 '駒沢オリンピック公園総合運動場陸上競技場': 20010,
 'とりぎんバードスタジアム': 16033,
 '富山県総合運動公園陸上競技場': 25250,
 'ＮＤソフトスタジアム山形': 21292,
 '山梨中銀スタジアム': 17000,
 '熊谷スポーツ文化公園陸上競技場': 15400,
 '神戸総合運動公園ユニバー記念競技場': 45000,
 'レベルファイブスタジアム': 22563,
 '宮城スタジアム': 49133,
 '岐阜メモリアルセンター長良川球技メドウ': 3560,
 '味の素フィールド西が丘': 7258,
 '福島県営あづま陸上競技場': 21000,
 '岡山県津山陸上競技場': 10000,
 '長崎県立総合運動公園陸上競技場': 20246,
 '長崎市総合運動公園かきどまり陸上競技場': 16000,
 '大垣市浅中公園総合グラウンド陸上競技場': 4300,
 '香川県立丸亀競技場': 22338,
 '北九州市立本城陸上競技場': 10202,
 '岐阜メモリアルセンター長良川競技場': 20000,
 '正田醤油スタジアム群馬': 15135,
 'エディオンスタジアム広島': 50000,
 '香川県立丸亀競技場': 22338}

# %%
stad_n = pd.DataFrame(train.groupby('stadium')['y'].count())

# %%
stad_sum = pd.DataFrame(train.groupby('stadium')['y'].sum())

# %%
stad_ave = pd.DataFrame(stad_sum['y'] / stad_n['y'])

# %%
stad_name = pd.DataFrame(stad_ave.index)

# %%
stad_ave = stad_ave.reset_index()
stad_ave.head()
# Out:
#          stadium             y
# 0  うまかな・よかなスタジアム   6503.866667
# 1   とりぎんバードスタジアム   3749.057143
# 2       エコパスタジアム  23119.000000
# 3   エディオンスタジアム広島  16380.945946
# 4     キンチョウスタジアム  13434.250000

# %%
stad_ave['stadium'] = stad_ave['stadium'].map(stadium_map)

# %%
stad_ave = stad_ave.rename( columns = {'stadium':'capa'})

# %%
stad_average = pd.concat([stad_ave, stad_name], axis = 1)
stad_average['mean'] = stad_average['y'] / stad_average['capa']
stad_average.head()
# Out:
#     capa             y        stadium      mean
# 0  32000   6503.866667  うまかな・よかなスタジアム  0.203246
# 1  16033   3749.057143   とりぎんバードスタジアム  0.233834
# 2  50889  23119.000000       エコパスタジアム  0.454303
# 3  50000  16380.945946   エディオンスタジアム広島  0.327619
# 4  19628  13434.250000     キンチョウスタジアム  0.684443

# %%
stad_average_1 = stad_average.drop(['capa','y'], axis = 1)
stad_average_1.head()
# Out:
#          stadium      mean
# 0  うまかな・よかなスタジアム  0.203246
# 1   とりぎんバードスタジアム  0.233834
# 2       エコパスタジアム  0.454303
# 3   エディオンスタジアム広島  0.327619
# 4     キンチョウスタジアム  0.684443

# %%
train_new = pd.merge(train_new, stad_average_1)

# %%
train_new.head()
# Out:
#    Unnamed: 0     id      y  year stage    match   gameday   time    home  \
# 0           0  13994  18250  2012    Ｊ１   第１節第１日  03/10(土)  14:04  ベガルタ仙台
# 1           1  14012  11831  2012    Ｊ１   第３節第１日  03/24(土)  13:03  ベガルタ仙台
# 2           2  14031  13147  2012    Ｊ１   第５節第１日  04/07(土)  14:03  ベガルタ仙台
# 3           3  14055  17192  2012    Ｊ１   第７節第１日  04/21(土)  19:04  ベガルタ仙台
# 4           4  14075  18525  2012    Ｊ１  第１０節第１日  05/06(日)  13:04  ベガルタ仙台
#
#         away       stadium                         tv  home_score  away_score  \
# 0   鹿島アントラーズ  ユアテックスタジアム仙台        スカパー／ｅ２／スカパー光／ＮＨＫ総合           1           0
# 1  大宮アルディージャ  ユアテックスタジアム仙台  スカパー／ｅ２／スカパー光（Ｊ　ＳＰＯＲＴＳ　１）           4           1
# 2     ジュビロ磐田  ユアテックスタジアム仙台  スカパー／ｅ２／スカパー光／ＮＨＫ仙台／ＮＨＫ静岡           2           2
# 3       ＦＣ東京  ユアテックスタジアム仙台      スカパー／ｅ２／スカパー光／ＮＨＫ　ＢＳ１           4           0
# 4    清水エスパルス  ユアテックスタジアム仙台        スカパー／ｅ２／スカパー光／ＮＨＫ仙台           0           1
#
# ...
