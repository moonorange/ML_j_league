# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns

from numpy import nan
import math


pd.set_option("max_columns", 100)
pd.set_option('max_rows',100)
pd.set_option('max_info_columns', 100)

# %%
train_1 = pd.read_csv("train_new.csv")

# %%
l_2d = [[35.6634009, 139.5254355],
[35.4707796, 139.6029698],
[33.7676604, 132.7968362],
[33.5859116, 130.4601782],
[38.336331, 140.3762032],
[36.17933560000001, 137.9164237],
[36.6226052, 137.1971531],
[36.3454214, 140.4117326],
[35.578201, 140.1234814],
[33.8907253, 130.7294251],
[36.5565798, 139.9858451],
[34.6792231, 133.9153905],
[36.4126918, 139.0522476],
[33.2007248, 131.6585636],
[34.9933731, 135.715662],
[35.3420762, 139.3431322],
[35.4413183, 136.7660782],
[34.1679659, 134.6153904],
[32.837431, 130.7993793],
[34.8103663, 135.54186],
[34.6567552, 135.1696527],
[34.7228006, 137.8789436],
[35.62127760000001, 138.5882628],
[34.4399378, 132.394889],
[35.9034227, 139.7162571],
[34.6122445, 135.5174433],
[35.4582068, 134.2209829],
[35.9919935, 140.6403308],
[37.8821496, 139.057993],
[35.5866165, 139.6506615],
[38.31909539999999, 140.8811375],
[35.9168106, 139.6297176],
[34.985127, 138.4809596],
[33.3725028, 130.5203189],
[35.8488404, 139.9756535],
[35.5110915, 139.6054998],
[32.8378824, 130.0401237],
[43.0072809, 141.4113189],
[35.0843699, 137.1703056],
[43.0186814, 141.4631858],
[35.5919093, 139.4386228],
[35.1223167, 136.9434324],
[35.6768092, 139.7150184],
[34.2613622, 133.7852714],
[35.6264719, 139.6602167],
[32.7945155, 130.7407644],
[34.7446525, 137.9687789],
[35.445248, 136.765075],
[35.767874, 139.708771],
[36.166373, 139.407552],
[34.6820321, 135.0756159],
[31.5649599, 130.5611608],
[33.2763806, 130.290322],
[35.0817839, 134.0174243],
[37.7248356, 140.3649354],
[38.3367298, 140.9537626],
[32.7752567, 129.8182539],
[35.3144948, 136.6046695]]

df_0_1 = pd.DataFrame(l_2d, columns=['latitude', "longitude"])

# %%
df_address = pd.DataFrame({"address_all" : ["東京都調布市西町376-3", "神奈川県横浜市神奈川区三ツ沢西町3-1", "愛媛県松山市上野町乙46",
                           "福岡県福岡市博多区東平尾公園2-1-1", "山形県天童市山王1-1", "長野県松本市神林5300", "富山県富山市南中田368",
                           "茨城県水戸市小吹町2058-1", "千葉県千葉市中央区川崎町1-20", "福岡県北九州市八幡西区御開4-16-1",
                           "栃木県宇都宮市清原工業団地32", "岡山県岡山市北区いずみ町2-1", "群馬県前橋市敷島町66", "大分県大分市大字横尾1351", 
                           "京都府京都市右京区西京極新明町29", "神奈川県平塚市大原1-1", "岐阜県岐阜市長良福光大野2675-28",
                           "徳島県鳴門市撫養町立岩字四枚61", "熊本県熊本市東区平山町2776", "大阪府吹田市千里万博公園5-2", 
                           "兵庫県神戸市兵庫区御崎町1-2-2", "静岡県磐田市新貝2500", "山梨県甲府市小瀬町840", "広島県広島市安佐南区大塚西5-1-1",
                           "埼玉県さいたま市緑区中野田500", "大阪府大阪市東住吉区長居公園1-1", "鳥取県鳥取市蔵田423", "茨城県鹿嶋市神向寺後山26-2",
                           "新潟県新潟市中央区清五郎67-12", "神奈川県川崎市中原区等々力1-1", "宮城県仙台市泉区七北田字柳78", 
                           "埼玉県さいたま市大宮区高鼻町4",  "静岡県静岡市清水区村松3880-1", "佐賀県鳥栖市京町812", "千葉県柏市日立台1-2-50",
                           "神奈川県横浜市港北区小机町3300", "長崎県諫早市宇都町27-1", "北海道札幌市豊平区羊ヶ丘1", "愛知県豊田市千石町7-2",
                           "北海道札幌市厚別区上野幌3条1-2-1", "東京都町田市野津田町2035", "愛知県名古屋市瑞穂区山下通5-1",
                           "東京都新宿区霞ヶ丘町10", "香川県丸亀市金倉町830", "東京都世田谷区駒沢公園1-1", "熊本県熊本市中央区水前寺5-23-3",
                           "静岡県袋井市愛野2300-1", "岐阜県岐阜市長良福光青襖2070-7", "東京都北区西が丘3-15-1", 
                           "埼玉県熊谷市上川上300 熊谷スポーツ文化公園内", "兵庫県神戸市須磨区緑台", "鹿児島県鹿児島市与次郎2-2-2", 
                           "佐賀県佐賀市日の出2-1-10", "岡山県津山市志戸部245", "福島県福島市佐原字神事場1", "宮城県宮城郡利府町菅谷字舘40-1", 
                           "長崎県長崎市柿泊町2210", "岐阜県大垣市浅中2-11-1"]})

# %%
df = pd.concat([df_address, df_0_1], axis = 1)
df
# Out:
#                  address_all   latitude   longitude
# 0              東京都調布市西町376-3  35.663401  139.525435
# 1        神奈川県横浜市神奈川区三ツ沢西町3-1  35.470780  139.602970
# 2               愛媛県松山市上野町乙46  33.767660  132.796836
# 3        福岡県福岡市博多区東平尾公園2-1-1  33.585912  130.460178
# 4                山形県天童市山王1-1  38.336331  140.376203
# 5               長野県松本市神林5300  36.179336  137.916424
# 6               富山県富山市南中田368  36.622605  137.197153
# 7            茨城県水戸市小吹町2058-1  36.345421  140.411733
# 8           千葉県千葉市中央区川崎町1-20  35.578201  140.123481
# 9        福岡県北九州市八幡西区御開4-16-1  33.890725  130.729425
# 10           栃木県宇都宮市清原工業団地32  36.556580  139.985845
# 11           岡山県岡山市北区いずみ町2-1  34.679223  133.915391
# 12               群馬県前橋市敷島町66  36.412692  139.052248
# 13            大分県大分市大字横尾1351  33.200725  131.658564
# 14         京都府京都市右京区西京極新明町29  34.993373  135.715662
# 15              神奈川県平塚市大原1-1  35.342076  139.343132
# 16       岐阜県岐阜市長良福光大野2675-28  35.441318  136.766078
# ...

# %%
# 各点の x 座標(経度)
points_x = []

# 各点の y 座標(緯度)
points_y = []

for i, row in df.iterrows():
    points_x.append(row['longitude'])
    points_y.append(row['latitude'])

# %%
#北海道
list_1 = []
def distance_1(a):
#     a = [points_x(経度), points_y]
#     b = [points_x_1(経度), points_y_1]
    b = [141.34694, 43.06417]
    for i  in range(len(a[0])):
        r = 6378 * 2 * math.pi 
        x = (b[0] - a[0][i])
        y = b[1] - a[1][i]
        d = math.sqrt(((x / 360) * r)**2 + ((y / 360) * r)**2)
        #d = r * math.sqrt( x**2 + y**2 ) / 360
        list_1.append(d)
    return list_1

#distance([points_x,points_y],[0.111,3.213213])
#この形で値渡す必要がある。

# %%
#東京
list_2 = []
def distance_2(a):
#     a = [points_x(経度), points_y]
#     b = [points_x_1(経度), points_y_1]
    b = [139.69167, 35.68944]
    for i  in range(len(a[0])):
        r = 6371 * 2 * math.pi 
        x = (b[0] - a[0][i])
        y = b[1] - a[1][i]
        d = math.sqrt(((x / 360) * r)**2 + ((y / 360) * r)**2)
        list_2.append(d)
    return list_2

#distance([points_x,points_y],[0.111,3.213213])
#この形で値渡す必要がある。

# %%
#名古屋
list_3 = []
def distance_3(a):
#     a = [points_x(経度), points_y]
#     b = [points_x_1(経度), points_y_1]
    b = [136.90667, 35.18028]
    for i  in range(len(a[0])):
        r = 6371 * 2 * math.pi 
        x = (b[0] - a[0][i])
        y = b[1] - a[1][i]
        d = math.sqrt(((x / 360) * r)**2 + ((y / 360) * r)**2)
        list_3.append(d)
    return list_3

#distance([points_x,points_y],[0.111,3.213213])
#この形で値渡す必要がある。

# %%
#大阪
list_4 = []
def distance_4(a):
#     a = [points_x(経度), points_y]
#     b = [points_x_1(経度), points_y_1]
    b = [135.52, 34.68639]
    for i  in range(len(a[0])):
        r = 6371 * 2 * math.pi 
        x = (b[0] - a[0][i])
        y = b[1] - a[1][i]
        d = math.sqrt(((x / 360) * r)**2 + ((y / 360) * r)**2)
        list_4.append(d)
    return list_4

#distance([points_x,points_y],[0.111,3.213213])
#この形で値渡す必要がある。

# %%
#福岡
list_5 = []
def distance_5(a):
#     a = [points_x(経度), points_y]
#     b = [points_x_1(経度), points_y_1]
    b = [130.41806, 33.60639]
    for i  in range(len(a[0])):
        r = 6371 * 2 * math.pi 
        x = (b[0] - a[0][i])
        y = b[1] - a[1][i]
        d = math.sqrt(((x / 360) * r)**2 + ((y / 360) * r)**2)
        list_5.append(d)
    return list_5

#distance([points_x,points_y],[0.111,3.213213])
#この形で値渡す必要がある。

# %%
hokkaido = distance_1([points_x,points_y])

# %%
hokkaido[0]
# Out:
# 848.4178784003539

# %%
hokkaido[19]
# Out:
# 1123.2785050974135

# %%
tokyo = distance_2([points_x, points_y])
nagoya = distance_3([points_x, points_y])
osaka = distance_4([points_x, points_y])
fukuoka = distance_5([points_x, points_y])

# %%
dist_h = pd.DataFrame(hokkaido)

# %%
dist_t = pd.DataFrame(tokyo)
dist_n = pd.DataFrame(nagoya)
dist_o = pd.DataFrame(osaka)
dist_f = pd.DataFrame(fukuoka)

# %%
dist = pd.concat([dist_h,dist_t,dist_n,dist_o,dist_f], axis = 1)

# %%
dist.head()
# Out:
#              0            0           0           0            0
# 0   848.417878    18.709829  296.107278  458.442319  1038.203291
# 1   867.281017    26.238256  301.549952  462.307660  1042.143368
# 2  1405.989903   795.894494  483.234115  319.570527   265.115018
# 3  1606.822772  1052.806769  738.415252  575.779843     5.207566
# 4   537.268399   304.004116  521.530505  675.501435  1225.855143

# %%
dist.columns = ['hokkaido', 'tokyo', 'nagoya', 'osaka', 'fukuoka']

# %%
dist.head()
# Out:
#       hokkaido        tokyo      nagoya       osaka      fukuoka
# 0   848.417878    18.709829  296.107278  458.442319  1038.203291
# 1   867.281017    26.238256  301.549952  462.307660  1042.143368
# 2  1405.989903   795.894494  483.234115  319.570527   265.115018
# 3  1606.822772  1052.806769  738.415252  575.779843     5.207566
# 4   537.268399   304.004116  521.530505  675.501435  1225.855143

# %%
dist.to_csv('distance.csv')

# %%
#年少人口
population_list_1 = [621, 155, 156, 297, 112, 139, 241, 376, 257, 258, 929, 778, 1517, 1161, 282, 133, 152, 106, 106,
                   278, 274, 488, 1041, 241, 207, 322, 1122, 732, 173, 119, 75, 88, 256, 378, 174, 91, 128, 176, 86, 687, 118, 
                   183, 244, 150, 153, 227, 249]

# %%
#労働人口
population_list_2 = [3261, 784, 749, 1458, 587, 653, 1157, 1789, 1225, 1189, 4573, 3848, 8862, 5820, 1359, 619, 691, 463,
                     504, 1216, 1210, 2219, 4686, 1089, 877, 1586, 5446, 3349, 819, 556, 332, 387, 1129, 1687, 793, 442, 567, 804, 
                     414, 3126, 491, 803, 1046, 674, 642, 963, 903]

# %%
list = []
for i,  k  in zip(population_list_1, population_list_2):
    list.append(i +k)

# %%
list
# Out:
# [3882,
#  939,
#  905,
#  1755,
#  699,
#  792,
#  1398,
#  2165,
#  1482,
#  1447,
#  5502,
#  4626,
#  10379,
#  6981,
#  1641,
#  752,
#  843,
#  569,
#  610,
#  1494,
#  1484,
#  2707,
#  5727,
#  1330,
#  1084,
#  1908,
#  6568,
#  4081,
#  992,
#  675,
#  407,
#  475,
#  1385,
#  2065,
#  967,
#  533,
#  695,
#  980,
#  500,
#  3813,
#  609,
#  986,
#  1290,
#  824,
#  795,
#  1190,
#  1152]

# %%
df_popu = pd.DataFrame(list)
df_popu
# Out:
#         0
# 0    3882
# 1     939
# 2     905
# 3    1755
# 4     699
# 5     792
# 6    1398
# 7    2165
# 8    1482
# 9    1447
# 10   5502
# 11   4626
# 12  10379
# 13   6981
# 14   1641
# 15    752
# 16    843
# 17    569
# 18    610
# 19   1494
# 20   1484
# 21   2707
# 22   5727
# 23   1330
# 24   1084
# 25   1908
# 26   6568
# 27   4081
# 28    992
# 29    675
# 30    407
# 31    475
# 32   1385
# 33   2065
# 34    967
# 35    533
# 36    695
# 37    980
# 38    500
# 39   3813
# 40    609
# 41    986
# 42   1290
# 43    824
# 44    795
# 45   1190
# 46   1152

# %%
df
# Out:
#                  address_all   latitude   longitude
# 0              東京都調布市西町376-3  35.663401  139.525435
# 1        神奈川県横浜市神奈川区三ツ沢西町3-1  35.470780  139.602970
# 2               愛媛県松山市上野町乙46  33.767660  132.796836
# 3        福岡県福岡市博多区東平尾公園2-1-1  33.585912  130.460178
# 4                山形県天童市山王1-1  38.336331  140.376203
# 5               長野県松本市神林5300  36.179336  137.916424
# 6               富山県富山市南中田368  36.622605  137.197153
# 7            茨城県水戸市小吹町2058-1  36.345421  140.411733
# 8           千葉県千葉市中央区川崎町1-20  35.578201  140.123481
# 9        福岡県北九州市八幡西区御開4-16-1  33.890725  130.729425
# 10           栃木県宇都宮市清原工業団地32  36.556580  139.985845
# 11           岡山県岡山市北区いずみ町2-1  34.679223  133.915391
# 12               群馬県前橋市敷島町66  36.412692  139.052248
# 13            大分県大分市大字横尾1351  33.200725  131.658564
# 14         京都府京都市右京区西京極新明町29  34.993373  135.715662
# 15              神奈川県平塚市大原1-1  35.342076  139.343132
# 16       岐阜県岐阜市長良福光大野2675-28  35.441318  136.766078
# ...

# %%
address_population = [10379, 6981, 980, 3813, 792, 1494, 752, 2165, 4626, 3813, 1482, 1385, 1447, 824, 1908,
              6981, 1330, 533, 1290, 6568, 4081, 2707, 610, 2065, 5502, 6568, 407, 2165, 1641, 6981, 1755, 
              5502, 2707, 609, 4626, 6981, 986, 3882, 5727, 3882, 10379, 5727, 10379, 695, 10379, 1290, 2707, 1484, 
              10379, 5502, 4081, 1190, 609, 1385, 1398, 1755, 986, 1484]

# %%
address_population_1 = np.array(address_population)

# %%
rate_list = 10379 / address_population_1
rate_list
# Out:
# array([ 1.        ,  1.48674975, 10.59081633,  2.72200367, 13.10479798,
#         6.94712182, 13.8018617 ,  4.79399538,  2.243623  ,  2.72200367,
#         7.00337382,  7.49386282,  7.17277125, 12.59587379,  5.43972746,
#         1.48674975,  7.8037594 , 19.4727955 ,  8.04573643,  1.58023752,
#         2.5432492 ,  3.83413373, 17.0147541 ,  5.02615012,  1.88640494,
#         1.58023752, 25.5012285 ,  4.79399538,  6.32480195,  1.48674975,
#         5.91396011,  1.88640494,  3.83413373, 17.04269294,  2.243623  ,
#         1.48674975, 10.52636917,  2.67362184,  1.81229265,  2.67362184,
#         1.        ,  1.81229265,  1.        , 14.93381295,  1.        ,
#         8.04573643,  3.83413373,  6.99393531,  1.        ,  1.88640494,
#         2.5432492 ,  8.72184874, 17.04269294,  7.49386282,  7.4241774 ,
#         5.91396011, 10.52636917,  6.99393531])

# %%
df_rate = pd.DataFrame(rate_list)

# %%
df_rate.columns = ["rate"]

# %%
df_new = pd.concat([df, df_rate], axis = 1)
df_new
# Out:
#                  address_all   latitude   longitude       rate
# 0              東京都調布市西町376-3  35.663401  139.525435   1.000000
# 1        神奈川県横浜市神奈川区三ツ沢西町3-1  35.470780  139.602970   1.486750
# 2               愛媛県松山市上野町乙46  33.767660  132.796836  10.590816
# 3        福岡県福岡市博多区東平尾公園2-1-1  33.585912  130.460178   2.722004
# 4                山形県天童市山王1-1  38.336331  140.376203  13.104798
# 5               長野県松本市神林5300  36.179336  137.916424   6.947122
# 6               富山県富山市南中田368  36.622605  137.197153  13.801862
# 7            茨城県水戸市小吹町2058-1  36.345421  140.411733   4.793995
# 8           千葉県千葉市中央区川崎町1-20  35.578201  140.123481   2.243623
# 9        福岡県北九州市八幡西区御開4-16-1  33.890725  130.729425   2.722004
# 10           栃木県宇都宮市清原工業団地32  36.556580  139.985845   7.003374
# 11           岡山県岡山市北区いずみ町2-1  34.679223  133.915391   7.493863
# 12               群馬県前橋市敷島町66  36.412692  139.052248   7.172771
# 13            大分県大分市大字横尾1351  33.200725  131.658564  12.595874
# ...

# %%
hokkaido_1 = np.array(dist.loc[:, ["hokkaido"]])

# %%
hokkaido_new = []
for i, k in zip(hokkaido_1, rate_list):
    hokkaido_new.append(i * k)
    
hokkaido_new
# Out:
# [array([848.4178784]),
#  array([1289.42983419]),
#  array([14890.58081636]),
#  array([4373.77748558]),
#  array([7040.79382513]),
#  array([5948.60773142]),
#  array([11772.59474636]),
#  array([3620.0523346]),
#  array([1894.45283971]),
#  array([4251.63018525]),
#  array([5183.06623682]),
#  array([9346.53181338]),
#  array([5618.04960589]),
#  array([19385.62556466]),
#  array([5959.18292299]),
#  array([1320.33835616]),
#  array([7725.60464451]),
#  array([24182.3479993]),
#  array([13158.02965321]),
#  array([1775.0468338]),
#  array([2953.60254111]),
#  array([3855.57096158]),
#  array([15034.25036373]),
#  array([6954.80419662]),
#  array([1542.17577061]),
#  array([1806.1000058]),
#  array([29586.78369309]),
#  array([3792.88411325]),
#  array([3988.51618121]),
#  array([1268.98298014]),
#  array([3138.8158071]),
#  array([1543.57862785]),
#  array([3658.70872623]),
#  array([27567.00694524]),
#  array([1834.31072279]),
#  array([1282.83421023]),
# ...

# %%
def kakezan(a, b):
    for i, k in zip(a, rate_list):
        b.append(i * k)
    return b

# %%
tokyo_new = []
tokyo_1 = np.array(dist.loc[:, ["tokyo"]])

# %%
kakezan(tokyo_1, tokyo_new)
# Out:
# [array([18.7098289]),
#  array([39.00972011]),
#  array([8429.17240529]),
#  array([2865.74389182]),
#  array([3983.91253003]),
#  array([1422.60920259]),
#  array([4087.42909737]),
#  array([519.2426065]),
#  array([111.24525394]),
#  array([2766.72274172]),
#  array([713.07654985]),
#  array([4886.31185333]),
#  array([769.96189355]),
#  array([11778.72334426]),
#  array([2441.54439437]),
#  array([81.34976483]),
#  array([2547.76222675]),
#  array([11474.63490833]),
#  array([8354.60502392]),
#  array([745.36243466]),
#  array([1311.73273251]),
#  array([875.84534718]),
#  array([2091.57546388]),
#  array([4137.40106736]),
#  array([45.18004876]),
#  array([757.50063198]),
#  array([15526.5708953]),
#  array([530.79650263]),
#  array([1605.20623834]),
#  array([18.30072636]),
#  array([1897.94573412]),
#  array([49.43166069]),
#  array([597.15635517]),
#  array([17926.30327645]),
#  array([81.24575286]),
#  array([32.74547709]),
#  array([11779.67764744]),
# ...

# %%
nagoya_new = []
nagoya_1 = np.array(dist.loc[:, ["nagoya"]])

osaka_new = []
osaka_1 = np.array(dist.loc[:, ["osaka"]])

fukuoka_new = []
fukuoka_1 = np.array(dist.loc[:, ["fukuoka"]])

# %%
kakezan(nagoya_1, nagoya_new)
# Out:
# [array([296.10727829]),
#  array([448.32931627]),
#  array([5117.843756]),
#  array([2009.96902818]),
#  array([6834.55190729]),
#  array([1097.28579809]),
#  array([2257.978168]),
#  array([1968.96417804]),
#  array([808.64523808]),
#  array([1909.99147276]),
#  array([2626.5031045]),
#  array([2527.29862263]),
#  array([1973.47100272]),
#  array([7855.99730692]),
#  array([729.22207745]),
#  array([403.68070515]),
#  array([257.27683979]),
#  array([5423.89425448]),
#  array([5852.09636774]),
#  array([248.46925523]),
#  array([513.04812819]),
#  array([458.10880206]),
#  array([3289.08152055]),
#  array([2555.27694782]),
#  array([608.54291484]),
#  array([263.72472075]),
#  array([7656.22276049]),
#  array([2036.78717655]),
#  array([2428.9635512]),
#  array([458.58076463]),
#  array([3330.38779945]),
#  array([591.70778371]),
#  array([676.31390703]),
#  array([12578.05797891]),
#  array([783.60523401]),
#  array([449.50722994]),
#  array([8491.92564681]),
# ...

# %%
kakezan(osaka_1, osaka_new)
# Out:
# [array([458.442319]),
#  array([687.33579752]),
#  array([3384.51275855]),
#  array([1567.27484603]),
#  array([8852.3098439]),
#  array([2181.05321729]),
#  array([3931.27302249]),
#  array([2753.51317919]),
#  array([1169.82655988]),
#  array([1469.84098187]),
#  array([3770.36929756]),
#  array([1337.10158054]),
#  array([3135.68931306]),
#  array([5794.79952608]),
#  array([220.19451747]),
#  array([641.26448549]),
#  array([1264.22900206]),
#  array([2257.58672718]),
#  array([4535.67486572]),
#  array([22.12046911]),
#  array([99.43077168]),
#  array([1005.82288806]),
#  array([6068.50109063]),
#  array([1751.9922314]),
#  array([916.47354009]),
#  array([13.03617489]),
#  array([4284.62654825]),
#  array([2816.81848936]),
#  array([3353.00528506]),
#  array([698.90606041]),
#  array([4258.6211017]),
#  array([899.85520212]),
#  array([1268.7729726]),
#  array([9796.40423012]),
#  array([1148.80198655]),
#  array([689.03418917]),
#  array([6769.17625232]),
# ...

# %%
kakezan(fukuoka_1, fukuoka_new)
# Out:
# [array([1038.20329112]),
#  array([1549.4063913]),
#  array([2807.78446313]),
#  array([14.17501264]),
#  array([16064.58400027]),
#  array([6123.88469762]),
#  array([11387.16810266]),
#  array([5523.77219959]),
#  array([2470.76968976]),
#  array([127.62424695]),
#  array([7796.97411174]),
#  array([3048.28770111]),
#  array([7241.02723296]),
#  array([1827.98786006]),
#  array([3312.36436174]),
#  array([1503.1265835]),
#  array([5733.92594337]),
#  array([9169.36253679]),
#  array([767.88609358]),
#  array([924.84689538]),
#  array([1376.17287669]),
#  array([3216.25841293]),
#  array([15920.76883325]),
#  array([1199.01504349]),
#  array([2009.01089079]),
#  array([913.30002636]),
#  array([11994.13191987]),
#  array([5595.58688534]),
#  array([6779.71107465]),
#  array([1561.03737541]),
#  array([7546.27241999]),
#  array([1992.07434432]),
#  array([3487.40070756]),
#  array([483.74231604]),
#  array([2449.17436069]),
#  array([1551.15540625]),
#  array([1002.41094469]),
# ...

# %%
hokkaido_ = pd.DataFrame(hokkaido_new)
hokkaido_
# Out:
#                0
# 0     848.417878
# 1    1289.429834
# 2   14890.580816
# 3    4373.777486
# 4    7040.793825
# 5    5948.607731
# 6   11772.594746
# 7    3620.052335
# 8    1894.452840
# 9    4251.630185
# 10   5183.066237
# 11   9346.531813
# 12   5618.049606
# 13  19385.625565
# 14   5959.182923
# 15   1320.338356
# 16   7725.604645
# 17  24182.347999
# 18  13158.029653
# 19   1775.046834
# 20   2953.602541
# 21   3855.570962
# 22  15034.250364
# 23   6954.804197
# 24   1542.175771
# 25   1806.100006
# 26  29586.783693
# 27   3792.884113
# 28   3988.516181
# 29   1268.982980
# 30   3138.815807
# 31   1543.578628
# 32   3658.708726
# 33  27567.006945
# 34   1834.310723
# 35   1282.834210
# 36  17863.979499
# 37     25.569359
# 38   1817.013509
# 39     37.151609
# 40    858.487653
# 41   1831.986128
# 42    842.165673
# 43  19291.465016
# 44    848.966329
# 45  13222.478217
# 46   3832.371677
# 47   6921.671253
# 48    832.422193
# 49   1504.624912
# 50   2963.710313
# ...

# %%
tokyo_ = pd.DataFrame(tokyo_new)
nagoya_ = pd.DataFrame(nagoya_new)
osaka_ = pd.DataFrame(osaka_new)
fukuoka_ = pd.DataFrame(fukuoka_new)

# %%
df_new_1 = pd.concat([hokkaido_, tokyo_], axis = 1)

# %%
df_new_2 = pd.concat([df_new_1, nagoya_], axis = 1)
df_new_3 = pd.concat([df_new_2, osaka_], axis = 1)

# %%
df_new_4 = pd.concat([df_new_3, fukuoka_], axis = 1)

# %%
df_new_4.columns = ["hokkaido", "tokyo", "nagoya", "osaka", "fukuoka"]

# %%
df_ = pd.concat([df, df_new_4], axis = 1)
df_
# Out:
#                  address_all   latitude   longitude      hokkaido  \
# 0              東京都調布市西町376-3  35.663401  139.525435    848.417878
# 1        神奈川県横浜市神奈川区三ツ沢西町3-1  35.470780  139.602970   1289.429834
# 2               愛媛県松山市上野町乙46  33.767660  132.796836  14890.580816
# 3        福岡県福岡市博多区東平尾公園2-1-1  33.585912  130.460178   4373.777486
# 4                山形県天童市山王1-1  38.336331  140.376203   7040.793825
# 5               長野県松本市神林5300  36.179336  137.916424   5948.607731
# 6               富山県富山市南中田368  36.622605  137.197153  11772.594746
# 7            茨城県水戸市小吹町2058-1  36.345421  140.411733   3620.052335
# 8           千葉県千葉市中央区川崎町1-20  35.578201  140.123481   1894.452840
# 9        福岡県北九州市八幡西区御開4-16-1  33.890725  130.729425   4251.630185
# 10           栃木県宇都宮市清原工業団地32  36.556580  139.985845   5183.066237
# 11           岡山県岡山市北区いずみ町2-1  34.679223  133.915391   9346.531813
# 12               群馬県前橋市敷島町66  36.412692  139.052248   5618.049606
# ...

# %%
stadium = pd.read_csv("stadium.csv")
stadium
# Out:
#                          name                   address   capa
# 0                 名古屋市瑞穂陸上競技場          愛知県名古屋市瑞穂区山下通5-1  20000
# 1                     豊田スタジアム              愛知県豊田市千石町7-2  40000
# 2                   フクダ電子アリーナ          千葉県千葉市中央区川崎町1-20  18500
# 3                    日立柏サッカー場            千葉県柏市日立台1-2-50  15349
# 4                  ニンジニアスタジアム              愛媛県松山市上野町乙46  15576
# 5                レベルファイブスタジアム       福岡県福岡市博多区東平尾公園2-1-1  22563
# 6                北九州市立本城陸上競技場       福岡県北九州市八幡西区御開4-16-1  10202
# 7           岐阜メモリアルセンター長良川競技場       岐阜県岐阜市長良福光大野2675-28  20000
# 8                 正田醤油スタジアム群馬               群馬県前橋市敷島町66  15135
# 9                エディオンスタジアム広島        広島県広島市安佐南区大塚西5-1-1  50000
# 10                      札幌ドーム             北海道札幌市豊平区羊ヶ丘1  39232
# 11                  札幌厚別公園競技場       北海道札幌市厚別区上野幌3条1-2-1  19620
# 12                ノエビアスタジアム神戸         兵庫県神戸市兵庫区御崎町1-2-2  30132
# 13             県立カシマサッカースタジアム           茨城県鹿嶋市神向寺後山26-2  40728
# ...

# %%
df__ = df_.rename(columns = {"address_all": "address"})

# %%
df_a = pd.merge(stadium, df__)

# %%
df_a
# Out:
#                          name                   address   capa   latitude  \
# 0                 名古屋市瑞穂陸上競技場          愛知県名古屋市瑞穂区山下通5-1  20000  35.122317
# 1                     豊田スタジアム              愛知県豊田市千石町7-2  40000  35.084370
# 2                   フクダ電子アリーナ          千葉県千葉市中央区川崎町1-20  18500  35.578201
# 3                    日立柏サッカー場            千葉県柏市日立台1-2-50  15349  35.848840
# 4                  ニンジニアスタジアム              愛媛県松山市上野町乙46  15576  33.767660
# 5                レベルファイブスタジアム       福岡県福岡市博多区東平尾公園2-1-1  22563  33.585912
# 6                北九州市立本城陸上競技場       福岡県北九州市八幡西区御開4-16-1  10202  33.890725
# 7           岐阜メモリアルセンター長良川競技場       岐阜県岐阜市長良福光大野2675-28  20000  35.441318
# 8                 正田醤油スタジアム群馬               群馬県前橋市敷島町66  15135  36.412692
# 9                エディオンスタジアム広島        広島県広島市安佐南区大塚西5-1-1  50000  34.439938
# 10                      札幌ドーム             北海道札幌市豊平区羊ヶ丘1  39232  43.007281
# 11                  札幌厚別公園競技場       北海道札幌市厚別区上野幌3条1-2-1  19620  43.018681
# ...

# %%
df_a = df_a.drop("address", axis = 1)

# %%
df_a = df_a.drop("latitude", axis = 1)

# %%
df_a = df_a.drop("longitude", axis = 1)

# %%
df_a = df_a.drop("capa", axis = 1)

# %%
df_a.head()
# Out:
#           name      hokkaido        tokyo       nagoya        osaka  \
# 0  名古屋市瑞穂陸上競技場   1831.986128   565.487626    13.831839   299.997048
# 1      豊田スタジアム   1817.013509   522.525389    56.533712   342.099545
# 2    フクダ電子アリーナ   1894.452840   111.245254   808.645238  1169.826560
# 3     日立柏サッカー場   1834.310723    81.245753   783.605234  1148.801987
# 4   ニンジニアスタジアム  14890.580816  8429.172405  5117.843756  3384.512759
#
#        fukuoka
# 0  1349.996239
# 1  1392.912559
# 2  2470.769690
# 3  2449.174361
# 4  2807.784463
